# %% [markdown]
# ## Starting Off
#
# Think of one lingering quetion you have about SQL and sedd it to our slack class channel.

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a search of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url = 'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = 'U1F8RNabNLQ1xoiZ4aU0eA'
api_key = 'MWsKI2UOfPh3dk-fo9clIPR1qpgWtoMYqJ9ASIpzS4A0USmzJ3SuFwKeSHBGviPWf_hFBj940yamvqe4ssszQO59x2kh--IWRu5CeUeoSRBnjYuuDCs-bdk42GPpXXYx'

# %%
# client_id = 'bVX1Jsfp4dkIOqw5HOVplg' #Your client ID goes here (as a string)
# api_key = 'RTzp-q-TgkJW_NFQogubFvZNRDziXyoR38VbtZMWibDI-FlvB25OE7GmafFEqhTL8_Bk2HlcX24-hRWLMP7Nc6WHO_VXMXldpPBjP0LoPv5EFFELMSI2oll8njhbXHYx' #Your api key goes here (as a string)

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = "Beauty & Spas"

#where do you want to perform this search
location = "New York City"

# what is your other parameter you want to search against
status = True

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "open_now" : status
            }

url_params
# Out:
# {'term': 'Beauty+&+Spas', 'location': 'New+York+City', 'open_now': True}

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'BqNXOy5WJjIoNTX_Xg2wOg',
#    'alias': 'nuansa-spa-new-york-2',
#    'name': 'Nuansa Spa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jjC0w5SufDSnxtLNsDhpNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nuansa-spa-new-york-2?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 183,
#    'categories': [{'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75755, 'longitude': -73.97752},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '605 Fifth Ave',
#     'address2': 'Fl 5',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['605 Fifth Ave', 'Fl 5', 'New York, NY 10017']},
#    'phone': '+12126021500',
#    'display_phone': '(212) 602-1500',
#    'distance': 5963.721671953748},
#   {'id': 'Nu6403eEBOQvI58_ly2p7w',
#    'alias': 'ohm-spa-new-york-4',
#    'name': 'Ohm Spa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WvlYJGj2qU64T4WyD7sx2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ohm-spa-new-york-4?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 232,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'skincare', 'title': 'Skin Care'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7345957, 'longitude': -73.9855511},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '205 E 16th St',
#     'address2': 'Ste M2A (Fl 2)',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 E 16th St',
#      'Ste M2A (Fl 2)',
#      'New York, NY 10003']},
#    'phone': '+12128459812',
#    'display_phone': '(212) 845-9812',
#    'distance': 3324.0945027090197},
#   {'id': 'lUnaFekz7RIVdoYA1q43TA',
#    'alias': 'halo-spa-nyc-new-york',
#    'name': 'Halo Spa NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nZgOnedTKLbrVDzfgvJRsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/halo-spa-nyc-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 2,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'threadingservices', 'title': 'Threading Services'},
#     {'alias': 'waxing', 'title': 'Waxing'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7228, 'longitude': -73.98572},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '20 Avenue A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 Avenue A', 'New York, NY 10009']},
#    'phone': '+16463636117',
#    'display_phone': '(646) 363-6117',
#    'distance': 2060.607430265408},
#   {'id': 'vFIuJD2_gVIf7fVXo89qhw',
#    'alias': 'caudalie-spa-café-and-wine-bar-new-york',
#    'name': 'Caudalie Spa Café & Wine Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B9iE-_6FiP241e9KDI5x4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caudalie-spa-caf%C3%A9-and-wine-bar-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 17,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'cosmetics', 'title': 'Cosmetics & Beauty Supply'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73973, 'longitude': -74.00774},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '823 Washington St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['823 Washington St', 'New York, NY 10014']},
#    'phone': '+12122428466',
#    'display_phone': '(212) 242-8466',
#    'distance': 3979.061392319531},
#   {'id': 'ZkI3V9xcL5r8Tw5kS0BgRw',
#    'alias': 'shibui-manhattan',
#    'name': 'Shibui',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XnsLHugXXPgJ5KeMUnfj1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shibui-manhattan?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 34,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71989, 'longitude': -74.01002},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '377 Greenwich St',
#     'address2': '',
#     'address3': '',
#     'city': 'Manhattan',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['377 Greenwich St', 'Manhattan, NY 10013']},
#    'phone': '+12129418900',
#    'display_phone': '(212) 941-8900',
#    'distance': 2069.8670863939224},
#   {'id': 'FEG5YfXwLIfQ61PZq4lCeA',
#    'alias': 'hideaway-spa-and-lounge-wall-street-new-york-4',
#    'name': 'Hideaway Spa & Lounge Wall Street',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/imy4sTOWNk8z7tP_dCVVwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hideaway-spa-and-lounge-wall-street-new-york-4?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 82,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'skincare', 'title': 'Skin Care'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7086054, 'longitude': -74.0136016},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '108 Greenwich St',
#     'address2': 'Fl 4',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 Greenwich St', 'Fl 4', 'New York, NY 10006']},
#    'phone': '+16469129912',
#    'display_phone': '(646) 912-9912',
#    'distance': 1665.047458668486},
#   {'id': 'aobUMZMqeNInArssVHuvng',
#    'alias': 'orient-retreat-womens-spa-and-wellness-center-flushing',
#    'name': "Orient Retreat Women's Spa and Wellness Center",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/j4h2oLt3ON9ekJ3NmS9KjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orient-retreat-womens-spa-and-wellness-center-flushing?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 130,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'skincare', 'title': 'Skin Care'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7602014035567,
#     'longitude': -73.8327660498359},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3720 Prince St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3720 Prince St', 'Fl 3', 'Flushing, NY 11354']},
#    'phone': '+17188880088',
#    'display_phone': '(718) 888-0088',
#    'distance': 14909.961865227197},
#   {'id': 'cDDsR10uuJSO4tZoIT8nIQ',
#    'alias': 'beauty-spa-new-york',
#    'name': 'Beauty Spa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sgMvNJXA23fNGqBdwbMrjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beauty-spa-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 35,
#    'categories': [{'alias': 'reflexology', 'title': 'Reflexology'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#     {'alias': 'tcm', 'title': 'Traditional Chinese Medicine'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.778, 'longitude': -73.98059},
#    'transactions': [],
#    'location': {'address1': '148 W 72nd St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['148 W 72nd St', 'Fl 2', 'New York, NY 10023']},
#    'phone': '+12128771338',
#    'display_phone': '(212) 877-1338',
#    'distance': 8138.180853479165},
#   {'id': 'mr2U0QKo8ZyV2w4_cOkhAw',
#    'alias': 'skn-spa-new-york',
#    'name': 'SKN Spa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AGd5ye6Qan-3yjGnSn0PLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/skn-spa-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 325,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'hairremoval', 'title': 'Hair Removal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76379, 'longitude': -73.99208},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '698 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['698 10th Ave', 'New York, NY 10019']},
#    'phone': '+12125811398',
#    'display_phone': '(212) 581-1398',
#    'distance': 6488.056765592851},
#   {'id': '8YHDVxA8qh03OBYlxS-RtQ',
#    'alias': 'bamford-haybarn-spa-brooklyn-2',
#    'name': 'Bamford Haybarn Spa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bxRap26YHiv0R85BqCB34g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bamford-haybarn-spa-brooklyn-2?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 26,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.701758, 'longitude': -73.995995},
#    'transactions': [],
#    'location': {'address1': '60 Furman St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Furman St', 'Brooklyn, NY 11201']},
#    'phone': '+13476962530',
#    'display_phone': '(347) 696-2530',
#    'distance': 434.33439215982486},
#   {'id': 'EDdR1Xd-7v_m4_qs3UY3Yw',
#    'alias': 'the-mandarin-spa-new-york',
#    'name': 'The Mandarin Spa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SCfQV0piEs6epm4HQWI27w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mandarin-spa-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 126,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'tcm', 'title': 'Traditional Chinese Medicine'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.756048, 'longitude': -73.980412},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '21 West 45th St',
#     'address2': 'Ste 501',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 West 45th St', 'Ste 501', 'New York, NY 10018']},
#    'phone': '+16463507187',
#    'display_phone': '(646) 350-7187',
#    'distance': 5747.089109584513},
#   {'id': 'VV8yib_qgXF9hVk1V9AB3g',
#    'alias': 'pure-qi-spa-brooklyn-2',
#    'name': 'Pure Qi Spa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XcVobT4XnfxX8rdtszkSow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pure-qi-spa-brooklyn-2?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 335,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72272, 'longitude': -73.94853},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '268 Driggs Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['268 Driggs Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183833822',
#    'display_phone': '(718) 383-3822',
#    'distance': 4307.627743618017},
#   {'id': 'VkhxFi1bEntwUmFtaFwUZA',
#    'alias': 'metro-beauty-lounge-forest-hills-6',
#    'name': 'Metro Beauty Lounge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t7Mjq701arhxTflriQxCdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/metro-beauty-lounge-forest-hills-6?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 23,
#    'categories': [{'alias': 'othersalons', 'title': 'Nail Salons'},
#     {'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'hair', 'title': 'Hair Salons'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71152, 'longitude': -73.85621},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '9603 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9603 Metropolitan Ave', 'Forest Hills, NY 11375']},
#    'phone': '+17187934563',
#    'display_phone': '(718) 793-4563',
#    'distance': 11654.24252195611},
#   {'id': 'wLDo9mjgv3zw_vfK1tQ5-A',
#    'alias': 'cynergy-spa-brooklyn',
#    'name': 'Cynergy Spa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0t7e6sbVQD9OWbDNCwj2BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cynergy-spa-brooklyn?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 120,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'skincare', 'title': 'Skin Care'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.687446, 'longitude': -73.976346},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '87 Fort Greene Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['87 Fort Greene Pl', 'Brooklyn, NY 11217']},
#    'phone': '+17184039242',
#    'display_phone': '(718) 403-9242',
#    'distance': 2508.947436533364},
#   {'id': 'SDrll4HJX9Xfzpsa3tT7SA',
#    'alias': 'rescue-spa-new-york',
#    'name': 'Rescue Spa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KNY10uPGtFNnYqovnl6C1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rescue-spa-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 108,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'hair', 'title': 'Hair Salons'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73828, 'longitude': -73.9891899},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '29 East 19th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29 East 19th St', 'New York, NY 10003']},
#    'phone': '+18667722766',
#    'display_phone': '(866) 772-2766',
#    'distance': 3682.030573032468},
#   {'id': 'xHRYw4lx7O81o8MfRTZgHg',
#    'alias': 'glo-boutique-spa-brooklyn',
#    'name': 'Glo Boutique Spa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/F8sL_bNW-2jnHqO7rBygVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/glo-boutique-spa-brooklyn?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 22,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'eyelashservice', 'title': 'Eyelash Service'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72038, 'longitude': -73.96051},
#    'transactions': [],
#    'location': {'address1': '74 N 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['74 N 8th St', 'Brooklyn, NY 11249']},
#    'phone': '+13478895050',
#    'display_phone': '(347) 889-5050',
#    'distance': 3296.3012878497193},
#   {'id': '2ciY6PMGU1OQdIdt1fuS_g',
#    'alias': 'savor-beauty-spa-new-york-4',
#    'name': 'Savor Beauty + Spa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/l7fZaa-KZuByVacLdgcAQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/savor-beauty-spa-new-york-4?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 121,
#    'categories': [{'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'makeupartists', 'title': 'Makeup Artists'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73571, 'longitude': -74.00756},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '327 W 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['327 W 11th St', 'New York, NY 10014']},
#    'phone': '+12123042887',
#    'display_phone': '(212) 304-2887',
#    'distance': 3557.502648012172},
#   {'id': 'CaEh6DNSCBkgF6kp5JOJ2A',
#    'alias': 'the-spa-at-mandarin-oriental-new-york-2',
#    'name': 'The Spa at Mandarin Oriental',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/90Dv1J8JpxYQvzgjSoJUag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-spa-at-mandarin-oriental-new-york-2?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 88,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.768818, 'longitude': -73.98304},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '80 Columbus Cir 60th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Columbus Cir 60th St', 'New York, NY 10023']},
#    'phone': '+12128058880',
#    'display_phone': '(212) 805-8880',
#    'distance': 7110.2610110349715},
#   {'id': 'glMirP1UezuJFmXfp61C8g',
#    'alias': 'serenity-beauty-spa-brooklyn',
#    'name': 'Serenity Beauty Spa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RUkfQmTA-YOkYrthC_RgyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/serenity-beauty-spa-brooklyn?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 134,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71456, 'longitude': -73.95668},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '211 N 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 N 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+17183884446',
#    'display_phone': '(718) 388-4446',
#    'distance': 3328.128515787437},
#   {'id': 'N1GD18mIhMYlaMykfMJ-lw',
#    'alias': 'pretty-please-new-york',
#    'name': 'Pretty Please',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b7F6YMNhuC2Mh9i4r_HlSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pretty-please-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 172,
#    'categories': [{'alias': 'skincare', 'title': 'Skin Care'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7432446, 'longitude': -73.9892983},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1133 Broadway',
#     'address2': 'Ste 415',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1133 Broadway', 'Ste 415', 'New York, NY 10010']},
#    'phone': '+16463636292',
#    'display_phone': '(646) 363-6292',
#    'distance': 4224.157972880005}],
#  'total': 3700,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'BqNXOy5WJjIoNTX_Xg2wOg',
#    'alias': 'nuansa-spa-new-york-2',
#    'name': 'Nuansa Spa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jjC0w5SufDSnxtLNsDhpNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nuansa-spa-new-york-2?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 183,
#    'categories': [{'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75755, 'longitude': -73.97752},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '605 Fifth Ave',
#     'address2': 'Fl 5',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['605 Fifth Ave', 'Fl 5', 'New York, NY 10017']},
#    'phone': '+12126021500',
#    'display_phone': '(212) 602-1500',
#    'distance': 5963.721671953748},
#   {'id': 'Nu6403eEBOQvI58_ly2p7w',
#    'alias': 'ohm-spa-new-york-4',
#    'name': 'Ohm Spa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WvlYJGj2qU64T4WyD7sx2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ohm-spa-new-york-4?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 232,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'skincare', 'title': 'Skin Care'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7345957, 'longitude': -73.9855511},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '205 E 16th St',
#     'address2': 'Ste M2A (Fl 2)',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 E 16th St',
#      'Ste M2A (Fl 2)',
#      'New York, NY 10003']},
#    'phone': '+12128459812',
#    'display_phone': '(212) 845-9812',
#    'distance': 3324.0945027090197},
#   {'id': 'lUnaFekz7RIVdoYA1q43TA',
#    'alias': 'halo-spa-nyc-new-york',
#    'name': 'Halo Spa NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nZgOnedTKLbrVDzfgvJRsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/halo-spa-nyc-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 2,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'threadingservices', 'title': 'Threading Services'},
#     {'alias': 'waxing', 'title': 'Waxing'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7228, 'longitude': -73.98572},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '20 Avenue A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 Avenue A', 'New York, NY 10009']},
#    'phone': '+16463636117',
#    'display_phone': '(646) 363-6117',
#    'distance': 2060.607430265408},
#   {'id': 'vFIuJD2_gVIf7fVXo89qhw',
#    'alias': 'caudalie-spa-café-and-wine-bar-new-york',
#    'name': 'Caudalie Spa Café & Wine Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B9iE-_6FiP241e9KDI5x4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caudalie-spa-caf%C3%A9-and-wine-bar-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 17,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'cosmetics', 'title': 'Cosmetics & Beauty Supply'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73973, 'longitude': -74.00774},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '823 Washington St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['823 Washington St', 'New York, NY 10014']},
#    'phone': '+12122428466',
#    'display_phone': '(212) 242-8466',
#    'distance': 3979.061392319531},
#   {'id': 'ZkI3V9xcL5r8Tw5kS0BgRw',
#    'alias': 'shibui-manhattan',
#    'name': 'Shibui',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XnsLHugXXPgJ5KeMUnfj1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shibui-manhattan?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 34,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71989, 'longitude': -74.01002},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '377 Greenwich St',
#     'address2': '',
#     'address3': '',
#     'city': 'Manhattan',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['377 Greenwich St', 'Manhattan, NY 10013']},
#    'phone': '+12129418900',
#    'display_phone': '(212) 941-8900',
#    'distance': 2069.8670863939224},
#   {'id': 'FEG5YfXwLIfQ61PZq4lCeA',
#    'alias': 'hideaway-spa-and-lounge-wall-street-new-york-4',
#    'name': 'Hideaway Spa & Lounge Wall Street',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/imy4sTOWNk8z7tP_dCVVwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hideaway-spa-and-lounge-wall-street-new-york-4?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 82,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'skincare', 'title': 'Skin Care'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7086054, 'longitude': -74.0136016},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '108 Greenwich St',
#     'address2': 'Fl 4',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 Greenwich St', 'Fl 4', 'New York, NY 10006']},
#    'phone': '+16469129912',
#    'display_phone': '(646) 912-9912',
#    'distance': 1665.047458668486},
#   {'id': 'aobUMZMqeNInArssVHuvng',
#    'alias': 'orient-retreat-womens-spa-and-wellness-center-flushing',
#    'name': "Orient Retreat Women's Spa and Wellness Center",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/j4h2oLt3ON9ekJ3NmS9KjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orient-retreat-womens-spa-and-wellness-center-flushing?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 130,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'skincare', 'title': 'Skin Care'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7602014035567,
#     'longitude': -73.8327660498359},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3720 Prince St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3720 Prince St', 'Fl 3', 'Flushing, NY 11354']},
#    'phone': '+17188880088',
#    'display_phone': '(718) 888-0088',
#    'distance': 14909.961865227197},
#   {'id': 'cDDsR10uuJSO4tZoIT8nIQ',
#    'alias': 'beauty-spa-new-york',
#    'name': 'Beauty Spa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sgMvNJXA23fNGqBdwbMrjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beauty-spa-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 35,
#    'categories': [{'alias': 'reflexology', 'title': 'Reflexology'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#     {'alias': 'tcm', 'title': 'Traditional Chinese Medicine'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.778, 'longitude': -73.98059},
#    'transactions': [],
#    'location': {'address1': '148 W 72nd St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['148 W 72nd St', 'Fl 2', 'New York, NY 10023']},
#    'phone': '+12128771338',
#    'display_phone': '(212) 877-1338',
#    'distance': 8138.180853479165},
#   {'id': 'mr2U0QKo8ZyV2w4_cOkhAw',
#    'alias': 'skn-spa-new-york',
#    'name': 'SKN Spa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AGd5ye6Qan-3yjGnSn0PLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/skn-spa-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 325,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'hairremoval', 'title': 'Hair Removal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76379, 'longitude': -73.99208},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '698 10th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['698 10th Ave', 'New York, NY 10019']},
#    'phone': '+12125811398',
#    'display_phone': '(212) 581-1398',
#    'distance': 6488.056765592851},
#   {'id': '8YHDVxA8qh03OBYlxS-RtQ',
#    'alias': 'bamford-haybarn-spa-brooklyn-2',
#    'name': 'Bamford Haybarn Spa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bxRap26YHiv0R85BqCB34g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bamford-haybarn-spa-brooklyn-2?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 26,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.701758, 'longitude': -73.995995},
#    'transactions': [],
#    'location': {'address1': '60 Furman St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Furman St', 'Brooklyn, NY 11201']},
#    'phone': '+13476962530',
#    'display_phone': '(347) 696-2530',
#    'distance': 434.33439215982486},
#   {'id': 'EDdR1Xd-7v_m4_qs3UY3Yw',
#    'alias': 'the-mandarin-spa-new-york',
#    'name': 'The Mandarin Spa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SCfQV0piEs6epm4HQWI27w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mandarin-spa-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 126,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'tcm', 'title': 'Traditional Chinese Medicine'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.756048, 'longitude': -73.980412},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '21 West 45th St',
#     'address2': 'Ste 501',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 West 45th St', 'Ste 501', 'New York, NY 10018']},
#    'phone': '+16463507187',
#    'display_phone': '(646) 350-7187',
#    'distance': 5747.089109584513},
#   {'id': 'VV8yib_qgXF9hVk1V9AB3g',
#    'alias': 'pure-qi-spa-brooklyn-2',
#    'name': 'Pure Qi Spa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XcVobT4XnfxX8rdtszkSow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pure-qi-spa-brooklyn-2?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 335,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72272, 'longitude': -73.94853},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '268 Driggs Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['268 Driggs Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183833822',
#    'display_phone': '(718) 383-3822',
#    'distance': 4307.627743618017},
#   {'id': 'VkhxFi1bEntwUmFtaFwUZA',
#    'alias': 'metro-beauty-lounge-forest-hills-6',
#    'name': 'Metro Beauty Lounge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t7Mjq701arhxTflriQxCdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/metro-beauty-lounge-forest-hills-6?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 23,
#    'categories': [{'alias': 'othersalons', 'title': 'Nail Salons'},
#     {'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'hair', 'title': 'Hair Salons'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71152, 'longitude': -73.85621},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '9603 Metropolitan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9603 Metropolitan Ave', 'Forest Hills, NY 11375']},
#    'phone': '+17187934563',
#    'display_phone': '(718) 793-4563',
#    'distance': 11654.24252195611},
#   {'id': 'wLDo9mjgv3zw_vfK1tQ5-A',
#    'alias': 'cynergy-spa-brooklyn',
#    'name': 'Cynergy Spa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0t7e6sbVQD9OWbDNCwj2BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cynergy-spa-brooklyn?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 120,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'skincare', 'title': 'Skin Care'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.687446, 'longitude': -73.976346},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '87 Fort Greene Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['87 Fort Greene Pl', 'Brooklyn, NY 11217']},
#    'phone': '+17184039242',
#    'display_phone': '(718) 403-9242',
#    'distance': 2508.947436533364},
#   {'id': 'SDrll4HJX9Xfzpsa3tT7SA',
#    'alias': 'rescue-spa-new-york',
#    'name': 'Rescue Spa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KNY10uPGtFNnYqovnl6C1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rescue-spa-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 108,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'hair', 'title': 'Hair Salons'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73828, 'longitude': -73.9891899},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '29 East 19th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29 East 19th St', 'New York, NY 10003']},
#    'phone': '+18667722766',
#    'display_phone': '(866) 772-2766',
#    'distance': 3682.030573032468},
#   {'id': 'xHRYw4lx7O81o8MfRTZgHg',
#    'alias': 'glo-boutique-spa-brooklyn',
#    'name': 'Glo Boutique Spa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/F8sL_bNW-2jnHqO7rBygVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/glo-boutique-spa-brooklyn?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 22,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'eyelashservice', 'title': 'Eyelash Service'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72038, 'longitude': -73.96051},
#    'transactions': [],
#    'location': {'address1': '74 N 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['74 N 8th St', 'Brooklyn, NY 11249']},
#    'phone': '+13478895050',
#    'display_phone': '(347) 889-5050',
#    'distance': 3296.3012878497193},
#   {'id': '2ciY6PMGU1OQdIdt1fuS_g',
#    'alias': 'savor-beauty-spa-new-york-4',
#    'name': 'Savor Beauty + Spa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/l7fZaa-KZuByVacLdgcAQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/savor-beauty-spa-new-york-4?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 121,
#    'categories': [{'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'makeupartists', 'title': 'Makeup Artists'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73571, 'longitude': -74.00756},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '327 W 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['327 W 11th St', 'New York, NY 10014']},
#    'phone': '+12123042887',
#    'display_phone': '(212) 304-2887',
#    'distance': 3557.502648012172},
#   {'id': 'CaEh6DNSCBkgF6kp5JOJ2A',
#    'alias': 'the-spa-at-mandarin-oriental-new-york-2',
#    'name': 'The Spa at Mandarin Oriental',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/90Dv1J8JpxYQvzgjSoJUag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-spa-at-mandarin-oriental-new-york-2?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 88,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.768818, 'longitude': -73.98304},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '80 Columbus Cir 60th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Columbus Cir 60th St', 'New York, NY 10023']},
#    'phone': '+12128058880',
#    'display_phone': '(212) 805-8880',
#    'distance': 7110.2610110349715},
#   {'id': 'glMirP1UezuJFmXfp61C8g',
#    'alias': 'serenity-beauty-spa-brooklyn',
#    'name': 'Serenity Beauty Spa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RUkfQmTA-YOkYrthC_RgyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/serenity-beauty-spa-brooklyn?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 134,
#    'categories': [{'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71456, 'longitude': -73.95668},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '211 N 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 N 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+17183884446',
#    'display_phone': '(718) 388-4446',
#    'distance': 3328.128515787437},
#   {'id': 'N1GD18mIhMYlaMykfMJ-lw',
#    'alias': 'pretty-please-new-york',
#    'name': 'Pretty Please',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b7F6YMNhuC2Mh9i4r_HlSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pretty-please-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#    'review_count': 172,
#    'categories': [{'alias': 'skincare', 'title': 'Skin Care'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7432446, 'longitude': -73.9892983},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1133 Broadway',
#     'address2': 'Ste 415',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1133 Broadway', 'Ste 415', 'New York, NY 10010']},
#    'phone': '+16463636292',
#    'display_phone': '(646) 363-6292',
#    'distance': 4224.157972880005}],
#  'total': 3700,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %% [markdown]
# Now let's go a bit further and start to preview what's stored in each of the values for these keys.

# %%
data = response.json()

# %%
for key in data.keys():
    print(key)
    value = response.json()[key] #Use standard dictionary formatting
    print(type(value)) #What type is it?
    print('\n') #Seperate out data
# Out:
# businesses
# <class 'list'>
#
#
# total
# <class 'int'>
#
#
# region
# <class 'dict'>

# %%
data['total']
# Out:
# 3700

# %% [markdown]
# Let's make sure our data is as expected by looking at a couple of different business by taking a slice of the data.

# %%
len(data['businesses'])
# Out:
# 20

# %% [markdown]
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a tuple with the name, display_address, and one other data point of your choice.

# %%
business = data['businesses'][10]

# %%
business
# Out:
# {'id': 'EDdR1Xd-7v_m4_qs3UY3Yw',
#  'alias': 'the-mandarin-spa-new-york',
#  'name': 'The Mandarin Spa',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SCfQV0piEs6epm4HQWI27w/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/the-mandarin-spa-new-york?adjust_creative=U1F8RNabNLQ1xoiZ4aU0eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=U1F8RNabNLQ1xoiZ4aU0eA',
#  'review_count': 126,
#  'categories': [{'alias': 'spas', 'title': 'Day Spas'},
#   {'alias': 'tcm', 'title': 'Traditional Chinese Medicine'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.756048, 'longitude': -73.980412},
#  'transactions': [],
#  'price': '$$',
#  'location': {'address1': '21 West 45th St',
#   'address2': 'Ste 501',
#   'address3': '',
#   'city': 'New York',
#   'zip_code': '10018',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['21 West 45th St', 'Ste 501', 'New York, NY 10018']},
#  'phone': '+16463507187',
#  'display_phone': '(646) 350-7187',
#  'distance': 5747.089109584513}

# %%
biz_tuple = (business['name'], ' '.join(business['location']['display_address']), business['price'])

# %%
biz_tuple
# Out:
# ('The Mandarin Spa', '21 West 45th St Ste 501 New York, NY 10018', '$$')

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(alist):
    # create a container to hold our parsed data
    parsed = []
    
    # loop through our business and parse each individual business
    for b in alist:
        #print(b['name'])
        tup = (b['name'], ' '.join(b['location']['display_address']), b['rating'])
        parsed.append(tup)
        
    return parsed
    
    # in the loop, add each individual parsed parsed business to our data container
    
    # return the container with all of the parsed results

# %%
parse_data(data['businesses'])
# Out:
# [('Nuansa Spa', '605 Fifth Ave Fl 5 New York, NY 10017', 5.0),
#  ('Ohm Spa', '205 E 16th St Ste M2A (Fl 2) New York, NY 10003', 4.5),
#  ('Halo Spa NYC', '20 Avenue A New York, NY 10009', 5.0),
#  ('Caudalie Spa Café & Wine Bar', '823 Washington St New York, NY 10014', 5.0),
#  ('Shibui', '377 Greenwich St Manhattan, NY 10013', 4.0),
#  ('Hideaway Spa & Lounge Wall Street',
#   '108 Greenwich St Fl 4 New York, NY 10006',
#   4.5),
#  ("Orient Retreat Women's Spa and Wellness Center",
#   '3720 Prince St Fl 3 Flushing, NY 11354',
#   4.5),
#  ('Beauty Spa', '148 W 72nd St Fl 2 New York, NY 10023', 3.5),
#  ('SKN Spa', '698 10th Ave New York, NY 10019', 4.5),
#  ('Bamford Haybarn Spa', '60 Furman St Brooklyn, NY 11201', 4.0),
#  ('The Mandarin Spa', '21 West 45th St Ste 501 New York, NY 10018', 4.5),
#  ('Pure Qi Spa', '268 Driggs Ave Brooklyn, NY 11222', 4.5),
#  ('Metro Beauty Lounge', '9603 Metropolitan Ave Forest Hills, NY 11375', 4.5),
#  ('Cynergy Spa', '87 Fort Greene Pl Brooklyn, NY 11217', 4.5),
#  ('Rescue Spa', '29 East 19th St New York, NY 10003', 4.0),
#  ('Glo Boutique Spa', '74 N 8th St Brooklyn, NY 11249', 5.0),
#  ('Savor Beauty + Spa', '327 W 11th St New York, NY 10014', 4.5),
#  ('The Spa at Mandarin Oriental',
#   '80 Columbus Cir 60th St New York, NY 10023',
#   4.0),
#  ('Serenity Beauty Spa', '211 N 4th St Brooklyn, NY 11211', 4.5),
#  ('Pretty Please', '1133 Broadway Ste 415 New York, NY 10010', 5.0)]
